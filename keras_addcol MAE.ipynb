# %% [markdown]
# # Init

# %%
from f_drosophila_infer import *
from f_data_prep import *
import seaborn as sns
from sklearn import linear_model
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import load_model
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
from numpy.random import seed
seed(1)
tf.random.set_seed(2)

# %%
matplotlib.rcParams.update({'font.size':20})
matplotlib.rcParams['legend.frameon'] = False

# %% [markdown]
# # Load data

# %%
data_all = np.loadtxt('../data_complete.txt')
all_bin = np.vsplit(data_all, 6)
all_init = np.vstack([all_bin[i] for i in range(5)])
all_diff = np.vstack([all_bin[i+1]-all_bin[i] for i in range(5)])

# %%
with open('./pickles/validation_cells.pkl', 'rb') as f:
    cells_v = pickle.load(f)

# %%
val = np.hstack([cells_v+(6078*i) for i in range(5)])
cells_tt = np.delete(range(6078), cells_v)
tr = np.hstack([cells_tt+(6078*i) for i in range(5)])

# %%
def make_quad(X):
    quad = np.zeros((int(X.shape[0]), int(X.shape[1] + (X.shape[1]*(X.shape[1]-1))/2)))
    quad[:, :X.shape[1]] = np.copy(X)
    col = X.shape[1]
    for i in range(X.shape[1]-1):
        for j in range(i+1, X.shape[1]):
            quad[:,col] = (X[:,i]*X[:,j])
            col += 1
    return quad

# %%
quad = make_quad(all_init)
quad_t = np.copy(quad[tr])
y_t = np.copy(all_diff[tr])
quad_v = np.copy(quad[val])
y_v = np.copy(all_diff[val])

# %%
# model = Sequential()
# model.add(Dense(1, activation='linear', input_dim=4950))
# model.compile(optimizer='SGD', loss='mean_absolute_error')
# hist = model.fit(quad_t, y_t[:,0:1], batch_size=50, epochs=200, validation_data=(quad_v, y_v[:,0:1]), verbose=0)

# yp = all_init[val][:,0:1] + model.predict(quad_v)
# yp[yp<0] = 0
# ya = all_init[val][:,0:1] + y_v[:,0:1]

# ferror = np.sum(np.abs(yp-ya))/np.sum(np.abs(ya))
# ferror

# %%
# model = Sequential()
# model.add(Dense(1, activation='linear', input_dim=4950))
# model.compile(optimizer='SGD', loss='mean_absolute_error')
# hist = model.fit(quad_t, y_t[:,0:1], batch_size=50, epochs=200, validation_data=(quad_v, y_v[:,0:1]), verbose=0)

# yp = all_init[val][:,0:1] + model.predict(quad_v)
# yp[yp<0] = 0
# ya = all_init[val][:,0:1] + y_v[:,0:1]

# ferror = np.sum(np.abs(yp-ya))/np.sum(np.abs(ya))
# ferror

# %% [markdown]
# # Add columns one by one
# - no early stopping
# - iterated until epoch=200

# %%
ferror_g1 = np.zeros(99)
for i in range(1,100):
    with open('./pickles/keras/addcol_mae/mae_%s.pkl' % i, 'rb') as f:
        res = pickle.load(f)
    yp = all_init[val][:,0:i] + res['pred']
    ya = all_init[val][:,0:i] + y_v[:,0:i]
    ferror_g1[i-1] = (np.sum(np.abs(yp-ya), axis=0)/np.sum(np.abs(ya), axis=0))[0]

# %% [markdown]
# ## Fractional error of Gene 1 as a function of # of columns included for training

# %%
plt.figure(figsize=(12,6))
plt.plot(range(1,100), ferror_g1, 'o-')
plt.xlabel('# of columns')
plt.ylabel('Fractional error of g1')
plt.show()

# %% [markdown]
# ## Train_loss and val_loss of Gene 1 (trained on output layer dim = 1)

# %%
with open('./pickles/keras/addcol_mae/mae_1.pkl', 'rb') as f:
    res = pickle.load(f)
plt.figure(figsize=(12,6))
plt.plot(range(len(res['hist']['loss'])), res['hist']['loss'], label='train loss')
plt.plot(range(len(res['hist']['loss'])), res['hist']['val_loss'], label='val loss')
plt.legend(bbox_to_anchor=(1,1))
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.show()

# %% [markdown]
# ## Fractional error
# - train on output layer dim = 99
# - no early stopping
# - trained with epoch = 200

# %%
with open('./pickles/keras/addcol_mae/mae_99.pkl', 'rb') as f:
    res = pickle.load(f)
yp = all_init[val] + res['pred']
yp[yp<0] = 0
ya = all_init[val] + y_v

ferror = np.sum(np.abs(yp-ya), axis=0)/np.sum(np.abs(ya), axis=0)

with open('./pickles/LAD_(99,99)_ttv.pkl', 'rb') as f:
    lad = pickle.load(f)

plt.figure(figsize=(12,6))
plt.plot(range(99), lad['ferror'], 'o-', linewidth=2, label='e-LAD')
plt.plot(range(99), ferror, 'o-', linewidth=2, label='Keras')
plt.xlabel('Gene index')
plt.ylabel('Fractional error')
plt.legend()
plt.show()

# %% [markdown]
# # Train-test-validation
# - early stopping, min_delta = 0, monitor='val_loss'
# - output layer dim = 99

# %%
with open('./pickles/keras/biowulf/ttv_mae.pkl', 'rb') as f:
    keras = pickle.load(f)

yp = all_init[val] + keras['pred']
yp[yp<0] = 0
ya = all_init[val] + y_v
error1 = np.abs(yp-ya)

ferror = np.sum(np.abs(yp-ya), axis=0)/np.sum(np.abs(ya), axis=0)

res = {'pred': yp,
       'error': error1,
      'ferror': ferror,
      'hist': keras['hist']}

with open('./pickles/keras/ttv_mae/ttv_mae.pkl', 'wb') as f:
    pickle.dump(res,f)

# %% [markdown]
# ## Fractional error, Distribution of $L1$ norm of errors in validation cells

# %%
with open('./pickles/LAD_(99,99)_ttv.pkl', 'rb') as f:
    lad = pickle.load(f)
    
with open('./pickles/keras/ttv_mae/ttv_mae.pkl', 'rb') as f:
    keras = pickle.load(f)

plt.figure(figsize=(12,6))
plt.plot(range(99), lad['ferror'], 'o-', linewidth=2, label='e-LAD')
plt.plot(range(99), keras['ferror'], 'o-', linewidth=2, label='Keras')
plt.xlabel('Gene index')
plt.ylabel('Fractional error')
plt.legend()
plt.show()

plt.figure(figsize=(6,6))
sns.distplot(np.sum(lad['error'], axis=1), bins=100, label='e-LAD')
sns.distplot(np.sum(keras['error'], axis=1), bins=100, label='Keras')
plt.xlabel('Error')
plt.ylabel('Probability density')
plt.legend()
plt.show()

print(stats.mannwhitneyu(np.sum(lad['error'], axis=1), np.sum(keras['error'], axis=1), alternative='less'))

# model = load_model('./savedmodels/ttv_mae/best_model.h5')
# w = model.weights[0].numpy()
# bias = model.weights[1].numpy()

# yp = all_init[val] + quad_v.dot(w) + bias
# yp[yp<0] = 0
# ya = all_init[val] + y_v

# ferror = np.sum(np.abs(yp-ya), axis=0)/np.sum(np.abs(ya), axis=0)

# error = np.abs(yp-ya)
# plt.figure(figsize=(6,6))
# sns.distplot(np.sum(error, axis=1), bins=100, label='Keras')
# sns.distplot(np.sum(lad['error'], axis=1), bins=100, label='e-LAD')
# plt.legend()
# plt.show()

# print(stats.mannwhitneyu(np.sum(lad['error'], axis=1), np.sum(error, axis=1), alternative='less'))
# Out:
# MannwhitneyuResult(statistic=4332653.0, pvalue=1.2735268708465776e-05)

# %% [markdown]
# ## Fractional errors
# - trained one-by one (output layer dim = 1)

# %%
diff_p = np.zeros((3040,99))
for i in range(99):
    with open('./pickles/keras/ttv_mae/%s.pkl' % i, 'rb') as f:
        res = pickle.load(f)
    diff_p[:,i:(i+1)] = res['pred']
yp = all_init[val] + diff_p
yp[yp<0] = 0
ya = all_init[val] + y_v

ferror = np.sum(np.abs(yp-ya), axis=0)/np.sum(np.abs(ya), axis=0)

plt.figure(figsize=(12,6))

with open('./pickles/LAD_(99,99)_ttv.pkl', 'rb') as f:
    lad = pickle.load(f)
plt.plot(range(99), lad['ferror'], 'o-', linewidth=2, label='e-LAD')
plt.plot(range(99), ferror, 'o-', linewidth=2, label='Keras')
plt.xlabel('Gene index')
plt.ylabel('Fractional error')
plt.legend()
plt.show()

# %% [markdown]
# # Hidden layer with nodes = [50, 100, 500, 1000]
# - train-test-validation
# - Early stopping with monitor='val_loss', min_delta=0

# %% [markdown]
# ## Fractional Error

# %%
with open('./pickles/LAD_(99,99)_ttv.pkl', 'rb') as f:
    lad = pickle.load(f)
    
plt.figure(figsize=(12,6))
plt.plot(range(99), lad['ferror'], 'o-', linewidth=2, label='e-LAD')

n_hidden = [50,100,500,1000,5000,10000]
for i in n_hidden:
    with open('./pickles/keras/ttv_mae/hidden/%s.pkl' % i, 'rb') as f:
        res = pickle.load(f)
    yp = all_init[val] + res['pred']
    yp[yp<0] = 0
    ya = all_init[val] + y_v
    ferror = np.sum(np.abs(yp-ya), axis=0)/np.sum(np.abs(ya), axis=0)
    plt.plot(range(99), ferror, 'o-', label = 'n_node = %s' % i)
plt.xlabel('Gene index')
plt.ylabel('Fractional error')
plt.legend(bbox_to_anchor=(1,1))
plt.show()

# %% [markdown]
# ## L1 Distributions e-LAD vs Keras_hidden

# %%
n_node = [50,100,500,1000,5000,10000]
for i in n_node:
    with open('./pickles/keras/ttv_mae/hidden/%s.pkl' % i, 'rb') as f:
        res = pickle.load(f)
    yp = all_init[val] + res['pred']
    ya = all_init[val] + y_v
    
    error = np.abs(yp-ya)
    plt.figure(figsize=(8,6))
    sns.distplot(np.sum(lad['error'], axis=1), bins=100, label='e-LAD')
    sns.distplot(np.sum(error, axis=1), bins=100, label='Keras (n_node = %s)' % i)
    plt.ylim(0,0.7)
    plt.xlabel('Error')
    plt.ylabel('Probability density')
    plt.legend(bbox_to_anchor=(1,1))
    plt.show()
    print(stats.mannwhitneyu(np.sum(lad['error'], axis=1), np.sum(error, axis=1), alternative='less'))
# Out:
# MannwhitneyuResult(statistic=1766935.0, pvalue=0.0)
# MannwhitneyuResult(statistic=4392552.0, pvalue=0.00042602929777607774)
# MannwhitneyuResult(statistic=4380228.0, pvalue=0.00021955296865177105)
# MannwhitneyuResult(statistic=4354179.0, pvalue=4.8889722445818296e-05)
# MannwhitneyuResult(statistic=4409604.0, pvalue=0.0010139011624637384)
# MannwhitneyuResult(statistic=4403660.0, pvalue=0.0007543949122723335)

# %% [markdown]
# ## L1 Distrbutions Keras_hidden

# %%
plt.figure(figsize=(8,6))
n_node = [50,100,500,1000,5000,10000]
for i in n_node:
    with open('./pickles/keras/ttv_mae/hidden/%s.pkl' % i, 'rb') as f:
        res = pickle.load(f)
    yp = all_init[val] + res['pred']
    ya = all_init[val] + y_v
    
    error = np.abs(yp-ya)
    sns.distplot(np.sum(error, axis=1), bins=100, label='n_node = %s' % i)
    plt.ylim(0,0.7)
    plt.legend(bbox_to_anchor=(1,1))
plt.xlabel('Error')
plt.ylabel('Probability density')
plt.show()

# %%
with open('./pickles/keras/ttv_mae/hidden/50.pkl', 'rb') as f:
    res = pickle.load(f)
yp = all_init[val] + res['pred']
ya = all_init[val] + y_v
error_50 = np.sum(np.abs(yp-ya), axis=1)

with open('./pickles/keras/ttv_mae/hidden/100.pkl', 'rb') as f:
    res = pickle.load(f)
yp = all_init[val] + res['pred']
ya = all_init[val] + y_v
error_100 = np.sum(np.abs(yp-ya), axis=1)

with open('./pickles/keras/ttv_mae/hidden/500.pkl', 'rb') as f:
    res = pickle.load(f)
yp = all_init[val] + res['pred']
ya = all_init[val] + y_v
error_500 = np.sum(np.abs(yp-ya), axis=1)

with open('./pickles/keras/ttv_mae/hidden/1000.pkl', 'rb') as f:
    res = pickle.load(f)
yp = all_init[val] + res['pred']
ya = all_init[val] + y_v
error_1000 = np.sum(np.abs(yp-ya), axis=1)

with open('./pickles/keras/ttv_mae/hidden/5000.pkl', 'rb') as f:
    res = pickle.load(f)
yp = all_init[val] + res['pred']
ya = all_init[val] + y_v
error_5000 = np.sum(np.abs(yp-ya), axis=1)

with open('./pickles/keras/ttv_mae/hidden/10000.pkl', 'rb') as f:
    res = pickle.load(f)
yp = all_init[val] + res['pred']
ya = all_init[val] + y_v
error_10000 = np.sum(np.abs(yp-ya), axis=1)

print(stats.mannwhitneyu(error_50, error_100))
print(stats.mannwhitneyu(error_100, error_500))
print(stats.mannwhitneyu(error_100, error_1000))
print(stats.mannwhitneyu(error_500, error_1000))
print(stats.mannwhitneyu(error_1000, error_5000))
print(stats.mannwhitneyu(error_5000, error_10000))
# Out:
# MannwhitneyuResult(statistic=1801587.0, pvalue=0.0)
# MannwhitneyuResult(statistic=4607192.0, pvalue=0.4211932136832476)
# MannwhitneyuResult(statistic=4580531.0, pvalue=0.2781217695026871)
# MannwhitneyuResult(statistic=4594052.0, pvalue=0.34795318635338124)
# MannwhitneyuResult(statistic=4558396.0, pvalue=0.18091550572507464)
# MannwhitneyuResult(statistic=4613245.0, pvalue=0.45604948440028664)

# %%
with open('./pickles/LAD_(99,99)_ttv.pkl', 'rb') as f:
    lad = pickle.load(f)
    
plt.figure(figsize=(12,6))
plt.plot(range(99), lad['ferror'], 'o-', linewidth=2, label='e-LAD')

n_layer = [1,2,3,4]
for i in n_layer:
    with open('./pickles/keras/ttv_mae/hidden/layers%s.pkl' % i, 'rb') as f:
        res = pickle.load(f)
    yp = all_init[val] + res['pred']
    yp[yp<0] = 0
    ya = all_init[val] + y_v
    ferror = np.sum(np.abs(yp-ya), axis=0)/np.sum(np.abs(ya), axis=0)
    plt.plot(range(99), ferror, 'o-', label = 'n_layers = %s' % (i+1))
plt.xlabel('Gene index')
plt.ylabel('Fractional error')
plt.legend(bbox_to_anchor=(1,1))
plt.show()

# %%
n_layer = [1,2,3,4]
for i in n_layer:
    with open('./pickles/keras/ttv_mae/hidden/layers%s.pkl' % i, 'rb') as f:
        res = pickle.load(f)
    yp = all_init[val] + res['pred']
    ya = all_init[val] + y_v
    
    error = np.abs(yp-ya)
    plt.figure(figsize=(8,6))
    sns.distplot(np.sum(lad['error'], axis=1), bins=100, label='e-LAD')
    sns.distplot(np.sum(error, axis=1), bins=100, label='Keras (n_layers = %s)' % (i+1))
    plt.ylim(0,0.75)
    plt.xlabel('Error')
    plt.ylabel('Probability density')
    plt.legend(bbox_to_anchor=(1,1))
    plt.show()
    print(stats.mannwhitneyu(np.sum(lad['error'], axis=1), np.sum(error, axis=1), alternative='less'))
# Out:
# MannwhitneyuResult(statistic=4410946.0, pvalue=0.0010828327979307847)
# MannwhitneyuResult(statistic=4207874.0, pvalue=8.000300193919922e-10)
# MannwhitneyuResult(statistic=4017050.0, pvalue=5.602041194601944e-19)
# MannwhitneyuResult(statistic=3822821.0, pvalue=1.0131021371392117e-31)
